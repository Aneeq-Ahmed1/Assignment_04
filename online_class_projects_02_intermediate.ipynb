# %% [markdown]
# <a href="https://colab.research.google.com/github/Aneeq-Ahmed1/Assignment_04/blob/master/online_class_projects_02_intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("High Low Game")

import random

rounds = 5

def main():
    print("Welcome to the High Low Game")
    print("----------------------------")

    your_score = 0

    for i in range(rounds):
        print("Round", i + 1)

        computer_num = random.randint(1, 100)
        your_num = random.randint(1, 100)
        print("Your number is", your_num)

        choice = input("Do you think your number is higher or lower than the computer's number? ")

        higher_and_correct = choice == "higher" and your_num > computer_num
        lower_and_correct = choice == "lower" and your_num < computer_num

        if higher_and_correct or lower_and_correct:
            print("You were right! The computer's number was", computer_num)
            your_score += 1
        else:
            print("That's incorrect. The computer's number was", computer_num)

        print("Your score is now", your_score)
        print()

    print("Thanks for playing!")

if __name__ == "__main__":
    main()
# Out:
# High Low Game
# Welcome to the High Low Game
# ----------------------------
# Round 1
# Your number is 24
# Do you think your number is higher or lower than the computer's number? 15
# That's incorrect. The computer's number was 49
# Your score is now 0
#
# Round 2
# Your number is 13
# Do you think your number is higher or lower than the computer's number? 13
# That's incorrect. The computer's number was 57
# Your score is now 0
#
# Round 3
# Your number is 83
# Do you think your number is higher or lower than the computer's number? 15
# That's incorrect. The computer's number was 2
# Your score is now 0
#
# Round 4
# Your number is 80
# Do you think your number is higher or lower than the computer's number? 5
# That's incorrect. The computer's number was 8
# Your score is now 0
#
# Round 5
# Your number is 16
# Do you think your number is higher or lower than the computer's number? 15
# That's incorrect. The computer's number was 80
# Your score is now 0
#
# Thanks for playing!

# %%
print("Planetary Weight Calculator")

def main():
  print("Welcome to the Planetary Weight Calculator")
  print("------------------------------------------")

earth_weight = float(input("Enter your weight on Earth: "))

gravity_ratios = {
    "Mercury":0.38,
    "Venus":0.91,
    "Mars":0.38,
    "Jupiter":2.34,
    "Saturn":1.06,
    "Uranus":0.92,
    "Neptune":1.19
}

print("\n Select a planet")
for planet in gravity_ratios:
    print(f'- {planet}')

planet_choice = input("Enter the name of the planet: ").title()

if planet_choice in gravity_ratios:
    new_weight = earth_weight * gravity_ratios[planet_choice]
    print(f'Your weight on {planet_choice} is {new_weight:.2f}kg')
else:
  print("Invalid planet choice")

if __name__ == "__main__":
  main()
# Out:
# Planetary Weight Calculator
# Enter your weight on Earth: 15
#
#  Select a planet
# - Mercury
# - Venus
# - Mars
# - Jupiter
# - Saturn
# - Uranus
# - Neptune
# Enter the name of the planet: Mars
# Your weight on Mars is 5.70kg
# Welcome to the Planetary Weight Calculator
# ------------------------------------------

# %%
print("Lists and Dicts")

my_list = ["apple","mango","orange","pear","peach"]

def access_element(my_list,index):
  """Returns the element at the specified index, or an error message if out of range."""
  if 0 <= index < len(my_list):
    return f'Element at index {index}: {my_list[index]}'
  return "Index out of range"

def modify_element(my_list,index,new_value):
  """Modifies the element at the specified index with the new value."""
  if 0 <= index < len(my_list):
    old_value = my_list[index]
    my_list[index] = new_value
    return f'Element at index {index} modified from {old_value} to {new_value}'
  return "Index out of range"

def slice_list(my_list,start,end):
  """Returns a new list containing the elements from the start index to the end index (exclusive)."""
  if 0 <= start < len(my_list) and 0 <= end <= len(my_list):
    return f'Sliced list: {my_list[start:end]}'
  return("Invalid slice indicates!")

def list_game():
  print("\n Welcome to the list maniputlation")

my_list = ["apple","mango","orange","pear","peach"]
while True:
    print("Current list " , my_list)

    print("Select an operation")
    print("1. Access Element")
    print("2. Modify Element")
    print("3. Slice List")
    print("4. Quit")

    choice = input("Enter your choice (1-4): ")

    if choice == "1":
        index = int(input("Enter the index of the element you want to access: "))
        print(access_element(my_list,index))
    elif choice == "2":
        index = int(input("Enter the index of the element you want to modify: "))
        new_value = input("Enter the new value for the element: ")
        print(modify_element(my_list,index,new_value))
    elif choice == "3":
        start = int(input("Enter the start index for the slice: "))
        end = int(input("Enter the end index for the slice: "))
        print(slice_list(my_list,start,end))
    elif choice == "4":
        print("Exiting the game,Thanks for playing.")
        break
    else:
        print("Invalid choice! please enter a number between i to 4.")


if __name__ == "__main__":
    list_game()
# Out:
# Lists and Dicts
# Current list  ['apple', 'mango', 'orange', 'pear', 'peach']
# Select an operation
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 1
# Enter the index of the element you want to access: 3
# Element at index 3: pear
# Current list  ['apple', 'mango', 'orange', 'pear', 'peach']
# Select an operation
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 2
# Enter the index of the element you want to modify: 1
# Enter the new value for the element: dragon fruit
# Element at index 1 modified from mango to dragon fruit
# Current list  ['apple', 'dragon fruit', 'orange', 'pear', 'peach']
# Select an operation
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 3
# Enter the start index for the slice: 4
# Enter the end index for the slice: 5
# Sliced list: ['peach']
# Current list  ['apple', 'dragon fruit', 'orange', 'pear', 'peach']
# Select an operation
# 1. Access Element
# 2. Modify Element
# 3. Slice List
# 4. Quit
# Enter your choice (1-4): 4
# Exiting the game,Thanks for playing.
#
#  Welcome to the list maniputlation
